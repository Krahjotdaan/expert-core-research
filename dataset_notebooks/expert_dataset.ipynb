# %%
import pandas as pd
from utils.preprocessing import *

# %% [markdown]
# ## Full Negatives

# %%
# Расширенное экспертное ядро: 60 примеров на класс (Всего 180)
# Маппинг: negative=0, neutral=1, positive=2

full_negative = [
    {"text": "Ужасное качество, товар сломался через день.", "label": 0},
    {"text": "Полное разочарование, деньги выброшены на ветер.", "label": 0},
    {"text": "Не рекомендую никому, сплошные недостатки.", "label": 0},
    {"text": "Сервис отвратительный, никто не отвечает на звонки.", "label": 0},
    {"text": "Товар пришел поврежденным, упаковка была вскрыта.", "label": 0},
    {"text": "Очень плохо, не соответствует описанию совсем.", "label": 0},
    {"text": "Зря потратил время и нервы, верните деньги.", "label": 0},
    {"text": "Катастрофа, а не продукт. Больше никогда не куплю.", "label": 0},
    {"text": "Функции не работают, брак с завода.", "label": 0},
    {"text": "Худшая покупка в моей жизни, крайне недоволен.", "label": 0},
    {"text": "Материал ужасный, все расползлось после первой стирки.", "label": 0},
    {"text": "Обман покупателей, характеристики неверные.", "label": 0},
    {"text": "Не работает вообще, пришлось выбросить.", "label": 0},
    {"text": "Грубое отношение персонала, больше ни ногой.", "label": 0},
    {"text": "Разочарован полностью, ожидал гораздо лучшего.", "label": 0},
    {"text": "Жуткий запах химии, невозможно использовать.", "label": 0},
    {"text": "Сломалось в первый же час использования.", "label": 0},
    {"text": "Цвет совершенно не тот, что на фото, выглядит дешево.", "label": 0},
    {"text": "Постоянные глюки, программа вылетает каждые пять минут.", "label": 0},
    {"text": "Доставка задержалась на месяц, извинений не последовало.", "label": 0},
    {"text": "Размерная сетка врет, вещь не налезла.", "label": 0},
    {"text": "Швы кривые, торчат нитки, сделано небрежно.", "label": 0},
    {"text": "Батарейки разрядились мгновенно, устройство бесполезно.", "label": 0},
    {"text": "Вернул товар обратно, слишком много дефектов.", "label": 0},
    {"text": "Звук хриплый, слушать невозможно.", "label": 0},
    {"text": "Пластик треснул при легком нажатии.", "label": 0},
    {"text": "Инструкция на непонятном языке, ничего не ясно.", "label": 0},
    {"text": "Цена завышена необоснованно, качество копеечное.", "label": 0},
    {"text": "Продавец игнорирует сообщения, сервис на нуле.", "label": 0},
    {"text": "Опасно для здоровья, вызвало аллергию сразу.", "label": 0},
    {"text": "Кошмар какой-то, даже включать страшно.", "label": 0},
    {"text": "Деньги на ветер, полная ерунда.", "label": 0},
    {"text": "Никому не советую, пустая трата ресурсов.", "label": 0},
    {"text": "Ужасная сборка, детали шатаются.", "label": 0},
    {"text": "Товар не стоит ни копейки, один обман.", "label": 0},
    {"text": "Разочарование года, хуже не бывает.", "label": 0},
    {"text": "Служба поддержки хамит, проблему не решают.", "label": 0},
    {"text": "Пришло не то, что заказывал, возврат долгий.", "label": 0},
    {"text": "Качество ужасное, просто мусор.", "label": 0},
    {"text": "Не выполняет заявленных функций вообще.", "label": 0},
    {"text": "Очень слабый материал, рвется руками.", "label": 0},
    {"text": "Брак очевиден, контроль качества отсутствует.", "label": 0},
    {"text": "Работает через раз, постоянно виснет.", "label": 0},
    {"text": "Упаковка разбита, товар поцарапан весь.", "label": 0},
    {"text": "Зря поверил отзывам, товар плохой.", "label": 0},
    {"text": "Неудобно пользоваться, эргономика нулевая.", "label": 0},
    {"text": "Быстро вышел из строя, гарантия не работает.", "label": 0},
    {"text": "Цвета тусклые, вид дешевый и неприятный.", "label": 0},
    {"text": "Шумит как трактор, спать невозможно.", "label": 0},
    {"text": "Комплектация неполная, частей не хватает.", "label": 0},
    {"text": "Ткань синтетическая, кожа потеет instantly.", "label": 0},
    {"text": "Кнопки залипают, сенсор не реагирует.", "label": 0},
    {"text": "Воняет клеем, проветриваю неделю.", "label": 0},
    {"text": "Фото и реальность — небо и земля, обман.", "label": 0},
    {"text": "Слишком дорогой для такого низкого качества.", "label": 0},
    {"text": "Расстроил всю семью, подарок испорчен.", "label": 0},
    {"text": "Ненадежный производитель, больше не возьму.", "label": 0},
    {"text": "Инструкции нет, пришлось гадать как включить.", "label": 0},
    {"text": "Мелкие детали отвалились сразу.", "label": 0},
    {"text": "Полный провал, не тратьте деньги.", "label": 0}
]

# %% [markdown]
# ## Full Neutrals

# %%
full_neutral = [
    {"text": "Товар обычный, ничего особенного, но и не плохой.", "label": 1},
    {"text": "Доставили вовремя, но упаковка была немного помята.", "label": 1},
    {"text": "За свою цену вполне нормально, претензий нет.", "label": 1},
    {"text": "Сойдет для разового использования, не более.", "label": 1},
    {"text": "Качество среднее, есть мелкие недочеты, но работает.", "label": 1},
    {"text": "Не знаю, что сказать, вроде неплохо, но могло быть лучше.", "label": 1},
    {"text": "Обычный товар, как и везде, без сюрпризов.", "label": 1},
    {"text": "Цвет отличается от фото, но размер подошел.", "label": 1},
    {"text": "Нормально, функционал базовый, свои задачи выполняет.", "label": 1},
    {"text": "Ни плохо ни хорошо, стандартный продукт.", "label": 1},
    {"text": "Доставка задержалась на день, но товар цел.", "label": 1},
    {"text": "Можно было сделать лучше, но и так сойдет.", "label": 1},
    {"text": "Среднее качество материалов, сборка нормальная.", "label": 1},
    {"text": "Ожидал большего, но за эти деньги приемлемо.", "label": 1},
    {"text": "Работает стабильно, дизайн простенький.", "label": 1},
    {"text": "Инструкция подробная, хотя сам товар средний.", "label": 1},
    {"text": "Упаковка хорошая, содержимое без восторгов.", "label": 1},
    {"text": "Функционал есть, но интерфейс неудобный.", "label": 1},
    {"text": "Купил по акции, за полную цену брать бы не стал.", "label": 1},
    {"text": "Соответствует описанию, но вау-эффекта нет.", "label": 1},
    {"text": "Использовать можно, но есть нюансы.", "label": 1},
    {"text": "Доставка быстрая, товар обычный.", "label": 1},
    {"text": "Неплохой вариант для подарка, если бюджет ограничен.", "label": 1},
    {"text": "Качество сборки нормальное, материалы дешевые.", "label": 1},
    {"text": "Работает как часы, но выглядит старомодно.", "label": 1},
    {"text": "В целом доволен, но мелкие косяки присутствуют.", "label": 1},
    {"text": "Типичный представитель своего класса, ничего нового.", "label": 1},
    {"text": "Цена адекватная, качество среднее.", "label": 1},
    {"text": "Подойдет для начинающих, профи не оценят.", "label": 1},
    {"text": "Нормальный товар, без нареканий и без похвалы.", "label": 1},
    {"text": "Вроде бы ничего, но и восторга не вызывает.", "label": 1},
    {"text": "Среднячок, ничего выдающегося.", "label": 1},
    {"text": "На троечку, пойдет для бытовых нужд.", "label": 1},
    {"text": "Есть плюсы и минусы, в сумме ноль.", "label": 1},
    {"text": "Неплохо, но могли бы сделать удобнее.", "label": 1},
    {"text": "Обычная вещь, каких много в магазинах.", "label": 1},
    {"text": "Функции свои выполняет, но без энтузиазма.", "label": 1},
    {"text": "Качество приемлемое, но не идеальное.", "label": 1},
    {"text": "Доставка средняя, товар обычный.", "label": 1},
    {"text": "Не пожалел о покупке, но и не обрадовался.", "label": 1},
    {"text": "Стандартное решение, ничего лишнего.", "label": 1},
    {"text": "Могло быть и лучше, но сойдет.", "label": 1},
    {"text": "Просто товар, без эмоций.", "label": 1},
    {"text": "Цена соответствует качеству, ничего сверхъестественного.", "label": 1},
    {"text": "Работает, но иногда тупит.", "label": 1},
    {"text": "Внешний вид нормальный, начинка средняя.", "label": 1},
    {"text": "Неплохой вариант, если других нет.", "label": 1},
    {"text": "Сборка крепкая, но дизайн скучный.", "label": 1},
    {"text": "Удобно, но материал мог бы быть лучше.", "label": 1},
    {"text": "В принципе нормально, мелких багов не заметил.", "label": 1},
    {"text": "Середина рынка, ни рыба ни мясо.", "label": 1},
    {"text": "За эти деньги ожидать большего глупо.", "label": 1},
    {"text": "Товар как товар, ничего особенного.", "label": 1},
    {"text": "Использую пока, претензий особых нет.", "label": 1},
    {"text": "Нормально, но не хватает лоска.", "label": 1},
    {"text": "Сойдет для дачи, для дома слабовато.", "label": 1},
    {"text": "Обычное качество, обычная доставка.", "label": 1},
    {"text": "Не впечатлило, но и не расстроило.", "label": 1},
    {"text": "Средний уровень, подойдет многим.", "label": 1},
    {"text": "Без наворотов, просто работает.", "label": 1}
]

# %% [markdown]
# ## Full Positives

# %%
full_positive = [
    {"text": "Отличный товар, полностью оправдал ожидания!", "label": 2},
    {"text": "Превосходное качество, всем рекомендую к покупке.", "label": 2},
    {"text": "Лучшая покупка за последнее время, я в восторге.", "label": 2},
    {"text": "Супер! Быстрая доставка и идеальный товар.", "label": 2},
    {"text": "Очень доволен, буду заказывать еще обязательно.", "label": 2},
    {"text": "Замечательный продукт, спасибо продавцу!", "label": 2},
    {"text": "Все работает идеально, качество на высоте.", "label": 2},
    {"text": "Просто чудо, а не вещь. Очень понравился.", "label": 2},
    {"text": "Рекомендую всем, соотношение цены и качества отличное.", "label": 2},
    {"text": "Благодарю за такой прекрасный сервис и товар.", "label": 2},
    {"text": "Пяти звезд мало, действительно высший класс.", "label": 2},
    {"text": "Именно то, что я искал. Очень рад покупке.", "label": 2},
    {"text": "Качество сборки потрясающее, материалы дорогие.", "label": 2},
    {"text": "Всем советую, не пожалеете ни секунды.", "label": 2},
    {"text": "Великолепно! Превзошло все мои надежды.", "label": 2},
    {"text": "Быстрая курьерская доставка, товар в идеале.", "label": 2},
    {"text": "Удобный, практичный и красивый. Спасибо!", "label": 2},
    {"text": "Работает безупречно уже месяц, никаких проблем.", "label": 2},
    {"text": "Лучшее предложение на рынке, однозначно брать.", "label": 2},
    {"text": "Приятно удивлен качеством за такую цену.", "label": 2},
    {"text": "Дизайн шикарный, функции все работают.", "label": 2},
    {"text": "Ребенок в восторге, игрушка качественная.", "label": 2},
    {"text": "Упаковано надежно, доставлено быстро, товар супер.", "label": 2},
    {"text": "Превосходно справляется со своими задачами.", "label": 2},
    {"text": "Однозначно пять баллов, рекомендую друзьям.", "label": 2},
    {"text": "Качество выше всяких похвал, очень доволен.", "label": 2},
    {"text": "Идеальный подарок, именинник счастлив.", "label": 2},
    {"text": "Надежный производитель, товар служит долго.", "label": 2},
    {"text": "Все четко, быстро и качественно. Молодцы!", "label": 2},
    {"text": "Превосходный выбор, буду покупать только у вас.", "label": 2},
    {"text": "Восхитительно! Лучше и придумать нельзя.", "label": 2},
    {"text": "Огромное спасибо, товар просто огонь!", "label": 2},
    {"text": "Качество бомбическое, всем доволен.", "label": 2},
    {"text": "Рекомендую однозначно, не пожалеете.", "label": 2},
    {"text": "Превзошел все мои ожидания, супер вещь.", "label": 2},
    {"text": "Отличный сервис, товар пришел быстро и целый.", "label": 2},
    {"text": "Очень крутой девайс, пользуюсь с удовольствием.", "label": 2},
    {"text": "Цена сказка, качество мечта.", "label": 2},
    {"text": "Сделано на совесть, видно что старались.", "label": 2},
    {"text": "Лучшее приобретение этого года!", "label": 2},
    {"text": "Все отлично, никаких минусов не нашел.", "label": 2},
    {"text": "Товар топ, буду брать еще.", "label": 2},
    {"text": "Прекрасное исполнение, радует глаз.", "label": 2},
    {"text": "Работает как швейцарские часы, надежно.", "label": 2},
    {"text": "Очень стильный и удобный, рекомендую!", "label": 2},
    {"text": "Качество превосходное, материалы приятные.", "label": 2},
    {"text": "Доставка молниеносная, товар без изъянов.", "label": 2},
    {"text": "Полный восторг, спасибо магазину!", "label": 2},
    {"text": "Идеальное сочетание цены и качества.", "label": 2},
    {"text": "Очень довольна покупкой, всем подругам рассказала.", "label": 2},
    {"text": "Товар просто супер, рекомендую всем знакомым.", "label": 2},
    {"text": "Высокое качество, быстрая работа, все супер.", "label": 2},
    {"text": "Замечательная вещь, пригодится в хозяйстве.", "label": 2},
    {"text": "Брал с опаской, но оказался отличным товаром.", "label": 2},
    {"text": "Все работает прекрасно, настройка простая.", "label": 2},
    {"text": "Очень качественный продукт, рекомендую к покупке.", "label": 2},
    {"text": "Превосходно! Никаких нареканий, одни плюсы.", "label": 2},
    {"text": "Спасибо за отличный товар и сервис!", "label": 2},
    {"text": "Товар огонь, качество на уровне.", "label": 2},
    {"text": "Лучший выбор в этой категории, однозначно.", "label": 2},
]

# %% [markdown]
# ## Split

# %%
expert_core_45 = []
expert_core_45.extend(full_negative[:15])
expert_core_45.extend(full_neutral[:15])
expert_core_45.extend(full_positive[:15])

df_expert_core_45 = pd.DataFrame(expert_core_45)

# %%
expert_core_90 = []
expert_core_90.extend(full_negative[:30])
expert_core_90.extend(full_neutral[:30])
expert_core_90.extend(full_positive[:30])

df_expert_core_90 = pd.DataFrame(expert_core_90)

# %%
expert_core_180 = []
expert_core_180.extend(full_negative)
expert_core_180.extend(full_neutral)
expert_core_180.extend(full_positive)

df_expert_core_180 = pd.DataFrame(expert_core_180)

# %%
splits = {'expert_core_45': df_expert_core_45, 'expert_core_90': df_expert_core_90, 'expert_core_180': df_expert_core_180}
apply_preprocessing(splits)
# Out:
# Запуск лемматизации и очистки...
#
# Обработка сплита: expert_core_45
# 100%|██████████| 45/45 [00:00<00:00, 790.99it/s]
#     Сохранение в lemmatized/expert_core_45_lemmatized.csv...
# Обработка сплита: expert_core_90
# 100%|██████████| 90/90 [00:00<00:00, 1207.31it/s]
#     Сохранение в lemmatized/expert_core_90_lemmatized.csv...
# Обработка сплита: expert_core_180
# 100%|██████████| 180/180 [00:00<00:00, 1331.69it/s]
#     Сохранение в lemmatized/expert_core_180_lemmatized.csv...
